# %%
import numpy as np
from sklearn.datasets import load_digits

# %%
dataset=load_digits()

# %%
print(dataset.data)
print(dataset.target)
print(dataset.data.shape)
print(dataset.images.shape)
dataimagelength=len(dataset.images)
print(dataimagelength)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]
# [0 1 2 ... 8 9 8]
# (1797, 64)
# (1797, 8, 8)
# 1797

# %%
import matplotlib.pyplot as plt
n=1600
plt.gray()
plt.matshow(dataset.images[n])
plt.show()
dataset.images[n]
# Out:
# array([[ 0.,  2., 13., 16., 12.,  0.,  0.,  0.],
#        [ 0.,  9., 15., 10., 16.,  3.,  0.,  0.],
#        [ 0.,  5.,  7.,  5., 16.,  3.,  0.,  0.],
#        [ 0.,  0.,  0., 10., 14.,  0.,  0.,  0.],
#        [ 0.,  0.,  5., 16.,  7.,  0.,  0.,  0.],
#        [ 0.,  0., 14., 16.,  1.,  3.,  7.,  1.],
#        [ 0.,  3., 16., 12., 10., 16., 11.,  1.],
#        [ 0.,  0., 13., 16., 13.,  7.,  1.,  0.]])

# %%
X=dataset.images.reshape((dataimagelength,-1))
X
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
Y=dataset.target
Y
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=0)
print(X_train.shape)
print(X_test.shape)
# Out:
# (1347, 64)
# (450, 64)

# %%
from sklearn import svm
model=svm.SVC(kernel='linear')#from sv machine we are using sv classifier
model.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
n=-9
result=model.predict(dataset.images[n].reshape((1,-1)))
plt.imshow(dataset.images[n],cmap=plt.cm.gray_r,interpolation='nearest')
plt.show()
print(result)
# Out:
# [4]

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print("accuracy of model is:{0}%".format(accuracy_score(Y_test,y_pred)*100))
# Out:
# accuracy of model is:97.11111111111111%

# %% [markdown]
# **Playing with different samples and kernels**

# %%
from sklearn import svm
model1=svm.SVC(kernel='linear')
model2=svm.SVC(kernel='rbf')
model3=svm.SVC(gamma= 'scale',C=2.0,degree=8)

model1.fit(X_train,Y_train)
model2.fit(X_train,Y_train)
model3.fit(X_train,Y_train)

y_pred1=model1.predict(X_test)
y_pred2=model2.predict(X_test)
y_pred3=model3.predict(X_test)

print("accuracy oif the model1 is:{0}%".format(accuracy_score(Y_test,y_pred1)*100))
print("accuracy oif the model2 is:{0}%".format(accuracy_score(Y_test,y_pred2)*100))
print("accuracy oif the model3 is:{0}%".format(accuracy_score(Y_test,y_pred3)*100))
# Out:
# accuracy oif the model1 is:97.11111111111111%
# accuracy oif the model2 is:99.11111111111111%
# accuracy oif the model3 is:99.11111111111111%
